# %%
# Import the necessary libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # import data

# %%
# import data
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
# values are read into a pandas dataframe. 
chipo = pd.read_csv(url, sep = '\t') #sep is \t because the values are tab-separated.

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# the first 5 rows of the table (default)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# show me the first 10 rows
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.info() # entries <= 4622 observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# # Turn the item price into a float

# %%
# a. Check the item price type
chipo.item_price.dtype
# Out:
# dtype('O')

# %%
# b. Create a lambda function and change the type of item price (you can use for loop)
dollarizer = lambda x: float(x[1:-1]) #x[1:-1]
chipo.item_price = chipo.item_price.apply(dollarizer)

# %%
chipo.head(15)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
# # another way to do it instead of lambada function 

# # clean the item_price column and transform it in a float
# prices = [float(value[1 : -1]) for value in chipo.item_price]

# %%
# c. Check the item price type
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
chipo.item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
# compute renue for the period in the dataset
revenue = (chipo['quantity']* chipo['item_price']).sum()
print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# Revenue was: $39237.02

# %%
# how many different items are sold? 
chipo['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
chipo['item_name'].value_counts().count()
# Out:
# 50

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('name of style') #https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#sns.set_style()

# %%
plt.figure(figsize=(8,10))
plt.style.use('dark_background')
sns.set_style('darkgrid')
ax = sns.countplot(y='item_name', data=chipo)

# %%
plt.figure(figsize=(10,4))
plt.style.use('dark_background')
#sns.set_style('darkgrid')
ax = sns.countplot(x='item_name', data=chipo)

# %% [markdown]
# # choose entries which satisify particular conditions

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75

# %%
# choose rows satisfy some conditions:
chipo[chipo['item_price'] > 10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
chipo['choice_description'][4]
# Out:
# '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]'

# %%
max(chipo['item_price'])
# Out:
# 44.25

# %%
min(chipo['item_price'])
# Out:
# 1.09

# %%
chipo[chipo['item_price'] == max(chipo['item_price'])]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
chipo[chipo['item_price'] == min(chipo['item_price'])]
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
chipo[(chipo['item_price'] == min(chipo['item_price'])) & (chipo['item_name'] == 'Canned Soda')]
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 28          14         1  Canned Soda       [Dr. Pepper]        1.09
# 53          24         1  Canned Soda           [Sprite]        1.09
# 107         47         1  Canned Soda       [Dr. Pepper]        1.09
# 117         51         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 126         55         1  Canned Soda        [Coca Cola]        1.09
# ...        ...       ...          ...                ...         ...
# 3897      1562         1  Canned Soda     [Mountain Dew]        1.09
# 3926      1575         1  Canned Soda       [Dr. Pepper]        1.09
# 3936      1578         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 4008      1604         1  Canned Soda        [Diet Coke]        1.09
# 4051      1621         1  Canned Soda           [Sprite]        1.09
#
# [84 rows x 5 columns]

# %%
chipo[(chipo['item_price'] == min(chipo['item_price'])) & (chipo['item_name'] == 'Canned Soda') 
     & (chipo['choice_description'] == '[Mountain Dew]')]
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 228        100         1  Canned Soda     [Mountain Dew]        1.09
# 246        108         1  Canned Soda     [Mountain Dew]        1.09
# 248        108         1  Canned Soda     [Mountain Dew]        1.09
# 261        113         1  Canned Soda     [Mountain Dew]        1.09
# 378        164         1  Canned Soda     [Mountain Dew]        1.09
# 807        332         1  Canned Soda     [Mountain Dew]        1.09
# 1057       435         1  Canned Soda     [Mountain Dew]        1.09
# 1511       614         1  Canned Soda     [Mountain Dew]        1.09
# 2206       889         1  Canned Soda     [Mountain Dew]        1.09
# 2584      1025         1  Canned Soda     [Mountain Dew]        1.09
# 3221      1288         1  Canned Soda     [Mountain Dew]        1.09
# 3897      1562         1  Canned Soda     [Mountain Dew]        1.09

# %% [markdown]
# # groupby

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
### Which was the most-ordered item? 
grouped_chipo = chipo.groupby('item_name')

# %%
grouped_chipo

# %%
print(grouped_chipo)

# %%
type(grouped_chipo)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
chipo.groupby('item_name').apply(print)
# Out:
#       order_id  quantity          item_name choice_description  item_price
# 298        129         1  6 Pack Soft Drink           [Sprite]        6.49
# 341        148         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 357        154         1  6 Pack Soft Drink             [Coke]        6.49
# 388        168         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 417        182         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 553        230         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 639        264         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 721        298         1  6 Pack Soft Drink           [Nestea]        6.49
# 743        306         1  6 Pack Soft Drink             [Coke]        6.49
# 879        363         1  6 Pack Soft Drink             [Coke]        6.49
# 1026       422         1  6 Pack Soft Drink           [Sprite]        6.49
# ...

# %%
chipo.groupby('item_name').sum()
# Out:
#                                        order_id  quantity  item_price
# item_name
# 6 Pack Soft Drink                         52322        55      356.95
# Barbacoa Bowl                             53972        66      672.36
# Barbacoa Burrito                          74718        91      894.75
# Barbacoa Crispy Tacos                      5613        12      120.21
# Barbacoa Salad Bowl                        9708        10      106.40
# Barbacoa Soft Tacos                       18725        25      250.46
# Bottled Water                            175944       211      302.56
# Bowl                                        472         4       29.60
# Burrito                                    1550         6       44.40
# Canned Soda                               76396       126      137.34
# Canned Soft Drink                        304753       351      438.75
# Carnitas Bowl                             62742        71      736.71
# ...

# %%
chipo.groupby('item_name').mean()
# Out:
#                                           order_id  quantity  item_price
# item_name
# 6 Pack Soft Drink                       968.925926  1.018519    6.610185
# Barbacoa Bowl                           817.757576  1.000000   10.187273
# Barbacoa Burrito                        821.076923  1.000000    9.832418
# Barbacoa Crispy Tacos                   510.272727  1.090909   10.928182
# Barbacoa Salad Bowl                     970.800000  1.000000   10.640000
# Barbacoa Soft Tacos                     749.000000  1.000000   10.018400
# Bottled Water                          1086.074074  1.302469    1.867654
# Bowl                                    236.000000  2.000000   14.800000
# Burrito                                 258.333333  1.000000    7.400000
# Canned Soda                             734.576923  1.211538    1.320577
# Canned Soft Drink                      1012.468439  1.166113    1.457641
# Carnitas Bowl                           922.676471  1.044118   10.833971
# ...

# %%
chipo.groupby('item_name').count()
# Out:
#                                        order_id  quantity  choice_description  \
# item_name
# 6 Pack Soft Drink                            54        54                  54
# Barbacoa Bowl                                66        66                  66
# Barbacoa Burrito                             91        91                  91
# Barbacoa Crispy Tacos                        11        11                  11
# Barbacoa Salad Bowl                          10        10                  10
# Barbacoa Soft Tacos                          25        25                  25
# Bottled Water                               162       162                   0
# Bowl                                          2         2                   2
# Burrito                                       6         6                   6
# Canned Soda                                 104       104                 104
# Canned Soft Drink                           301       301                 301
# ...

# %%
chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False)
# Out:
#                                        order_id  quantity  item_price
# item_name
# Chicken Bowl                             713926       761     7342.73
# Chicken Burrito                          497303       591     5575.82
# Chips and Guacamole                      449959       506     2201.04
# Steak Burrito                            328437       386     3851.43
# Canned Soft Drink                        304753       351      438.75
# Chips                                    208004       230      494.34
# Steak Bowl                               193752       221     2260.19
# Bottled Water                            175944       211      302.56
# Chips and Fresh Tomato Salsa             100419       130      361.36
# Canned Soda                               76396       126      137.34
# Chicken Salad Bowl                       117104       123     1228.75
# Chicken Soft Tacos                        98395       120     1108.09
# ...

# %%
# What was the most ordered item in the choice_description column?

c = chipo.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Diet Coke 159
# Out:
#                     order_id  quantity  item_price
# choice_description
# [Diet Coke]           123455       159      326.71

# %%
import matplotlib.pyplot as plt
from collections import Counter

# %%
# set this so the 
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
# Create a scatterplot with the number of items orderered per order price
# Hint: Price should be in the X-axis and Items ordered in the Y-axis

# then groupby the orders and sum
orders = chipo.groupby('order_id').sum()

# creates the scatterplot
# plt.scatter(orders.quantity, orders.item_price, s = 50, c = 'green')
plt.scatter(x = orders.item_price, y = orders.quantity, s = 50, c = 'green')

# Set the title and labels
plt.xlabel('Order Price')
plt.ylabel('Items ordered')
plt.title('Number of items ordered per order price')
plt.ylim(0)
# Out:
# (0, 36.7178857951459)

# %%
# homework 

# Q1 select only the products with quantity equals to 1
# Q2 how many items which has quantity equals to 1 (which you found in question 1)
# Q3 how many unique iterms in answer that you found in question 1? 
# Q4 What was the quantity of the most expensive item ordered?
# Q5 How many times did someone order more than one Canned Soda?
# Q6 How many times was a Veggie Salad Bowl ordered?

# %%
#Q1
quantity_1_list = chipo[chipo['quantity'] == 1]
quantity_1_list
chipo[chipo['quantity'] == 1]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#Q2
len(quantity_1_list)
# Out:
# 4355

# %%
#Q3
chipo[chipo['quantity'] == 1].value_counts()
#Q4
chipo[chipo['item_price'] == max(chipo['item_price'])]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
#Q5
chipo[(chipo['quantity'] > 1) & (chipo['item_name'] == 'Canned Soda')]
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 18           9         2  Canned Soda           [Sprite]        2.18
# 51          23         2  Canned Soda     [Mountain Dew]        2.18
# 162         73         2  Canned Soda        [Diet Coke]        2.18
# 171         76         2  Canned Soda  [Diet Dr. Pepper]        2.18
# 350        150         2  Canned Soda        [Diet Coke]        2.18
# 352        151         2  Canned Soda        [Coca Cola]        2.18
# 698        287         2  Canned Soda        [Coca Cola]        2.18
# 700        288         2  Canned Soda        [Coca Cola]        2.18
# 909        376         2  Canned Soda     [Mountain Dew]        2.18
# 1091       450         2  Canned Soda       [Dr. Pepper]        2.18
# 1092       450         2  Canned Soda        [Coca Cola]        2.18
# 1944       787         2  Canned Soda       [Dr. Pepper]        2.18
# 2135       859         2  Canned Soda        [Diet Coke]        2.18
# ...

# %%
#Q6
chipo[chipo['item_name'] == 'Veggie Salad Bowl']
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...
